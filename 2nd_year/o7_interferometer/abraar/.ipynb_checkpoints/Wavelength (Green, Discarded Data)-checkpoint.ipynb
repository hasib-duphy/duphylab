# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# %%
f = 20 

data = pd.DataFrame()
data['n'] = np.arange(0,241,20)
data['D_ge (mm)'] = pd.Series([26.1, 25.98, 25.86, 25.75, 25.64, 25.53,
                 25.41, 25.29, 25.16, 25.05, 24.93, 24.81]).reindex(data.index)

data['D_gc (mm)'] = pd.Series([24.35, 24.53, 24.73, 24.85, 24.98, 25.12,
                 25.25, 25.38, 25.53, 25.71, 25.85,
                 26.03, 26.19]).reindex(data.index)


data['ΔD_ge (mm)'] = data.loc[0,'D_ge (mm)'] - data['D_ge (mm)']
data['ΔD_gc (mm)'] = - data.loc[0,'D_gc (mm)'] + data['D_gc (mm)']

data
# Out:
#       n  D_ge (mm)  D_gc (mm)  ΔD_ge (mm)  ΔD_gc (mm)
# 0     0      26.10      24.35        0.00        0.00
# 1    20      25.98      24.53        0.12        0.18
# 2    40      25.86      24.73        0.24        0.38
# 3    60      25.75      24.85        0.35        0.50
# 4    80      25.64      24.98        0.46        0.63
# 5   100      25.53      25.12        0.57        0.77
# 6   120      25.41      25.25        0.69        0.90
# 7   140      25.29      25.38        0.81        1.03
# 8   160      25.16      25.53        0.94        1.18
# 9   180      25.05      25.71        1.05        1.36
# 10  200      24.93      25.85        1.17        1.50
# 11  220      24.81      26.03        1.29        1.68
# 12  240        NaN      26.19         NaN        1.84

# %%
data_e = data[['n', 'ΔD_ge (mm)']].dropna()
data_c = data[['n', 'ΔD_gc (mm)']].dropna()

x_ge = data_e['n'].to_numpy()
y_ge = data_e['ΔD_ge (mm)'].to_numpy()*1e-3

x_gc = data_c['n'].to_numpy()
y_gc = data_c['ΔD_gc (mm)'].to_numpy()*1e-3

def formula(n,λ):
    return 0.5*f*λ*n

para, para_cov = curve_fit(formula, x_ge, y_ge, [600e-9])
λ_e = para[0]
print('λ_e =', λ_e)

para, para_cov = curve_fit(formula, x_gc, y_gc, [600e-9])
λ_c = para[0]
print('λ_c =', λ_c)

plt.plot(x_ge,y_ge,'.', color = "red", label = "Data (Expanding)")
plt.plot(x_gc,y_gc,'.', color = "blue", label = "Data (Collapsing)")

x_reg = np.linspace(0,241,10)
y_reg = formula(x_reg, λ_e)
plt.plot(x_reg,y_reg, '-', color = "red", label = "Fit (Expanding)")
y_reg = formula(x_reg, λ_c)
plt.plot(x_reg,y_reg, '-', color = "blue", label = "Fit (Collapsing)")

plt.legend()
plt.show()
# Out:
# λ_e = 5.831027668002262e-07
# λ_c = 7.589230769170662e-07

# %%
table = data[['n', 'ΔD_ge (mm)']].rename(columns={'n': 'x', 
                                               'ΔD_ge (mm)':'y'}).dropna()

table['xi^2'] = table['x']**2
table['xiyi'] = table['x']*table['y']
sum_x2 = table['xi^2'].sum()
sum_xy = table['xiyi'].sum()


slope = sum_xy/sum_x2


print(f'sum_x2 = {sum_x2}')
print(f'sum_xy = {sum_xy}')
print(f'slope = {slope}')

table
# Out:
# sum_x2 = 202400
# sum_xy = 1180.2000000000019
# slope = 0.005831027667984199
#       x     y   xi^2   xiyi
# 0     0  0.00      0    0.0
# 1    20  0.12    400    2.4
# 2    40  0.24   1600    9.6
# 3    60  0.35   3600   21.0
# 4    80  0.46   6400   36.8
# 5   100  0.57  10000   57.0
# 6   120  0.69  14400   82.8
# 7   140  0.81  19600  113.4
# 8   160  0.94  25600  150.4
# 9   180  1.05  32400  189.0
# 10  200  1.17  40000  234.0
# 11  220  1.29  48400  283.8

# %%
table = data[['n', 'ΔD_gc (mm)']].rename(columns={'n': 'x', 
                                               'ΔD_gc (mm)':'y'}).dropna()

table['xi^2'] = table['x']**2
table['xiyi'] = table['x']*table['y']
sum_x2 = table['xi^2'].sum()
sum_xy = table['xiyi'].sum()


slope = sum_xy/sum_x2


print(f'sum_x2 = {sum_x2}')
print(f'sum_xy = {sum_xy}')
print(f'slope = {slope}')

table
# Out:
# sum_x2 = 260000
# sum_xy = 1973.199999999999
# slope = 0.007589230769230765
#       x     y   xi^2   xiyi
# 0     0  0.00      0    0.0
# 1    20  0.18    400    3.6
# 2    40  0.38   1600   15.2
# 3    60  0.50   3600   30.0
# 4    80  0.63   6400   50.4
# 5   100  0.77  10000   77.0
# 6   120  0.90  14400  108.0
# 7   140  1.03  19600  144.2
# 8   160  1.18  25600  188.8
# 9   180  1.36  32400  244.8
# 10  200  1.50  40000  300.0
# 11  220  1.68  48400  369.6
# 12  240  1.84  57600  441.6
